# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("house pricing delhi- MagicBricks.csv")

# %%
df.head()
# Out:
#      Area  BHK  Bathroom Furnishing    Location       District  \
# 0   950.0    2       2.0  Furnished  Karol Bagh  Central Delhi
# 1   535.0    2       1.0  Furnished  Karol Bagh  Central Delhi
# 2  1280.0    3       3.0  Furnished  Karol Bagh  Central Delhi
# 3  1135.0    3       3.0  Furnished  Karol Bagh  Central Delhi
# 4  1135.0    3       3.0  Furnished  Karol Bagh  Central Delhi
#
#                                             Locality  Parking         Status  \
# 0  DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0  Ready_to_move
# 1                              Dev Nagar, Karol Bagh      1.0  Ready_to_move
# 2                                         Karol Bagh      2.0  Ready_to_move
# 3                          The Amaryllis, Karol Bagh      2.0   Almost_ready
# 4                          The Amaryllis, Karol Bagh      2.0   Almost_ready
#
#     Transaction           Type  Per_Sqft     Price
# 0        Resale      Apartment    8761.0  12500000
# 1  New_Property      Apartment    7290.0   3900000
# 2        Resale  Builder_Floor   14092.0  15000000
# 3        Resale      Apartment   22222.0  25000000
# 4        Resale      Apartment   22222.0  25000000

# %%
df.shape
# Out:
# (1214, 13)

# %%
df.dtypes
# Out:
# Area           float64
# BHK              int64
# Bathroom       float64
# Furnishing      object
# Location        object
# District        object
# Locality        object
# Parking        float64
# Status          object
# Transaction     object
# Type            object
# Per_Sqft       float64
# Price            int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Area', 'BHK', 'Bathroom', 'Furnishing', 'Location', 'District',
#        'Locality', 'Parking', 'Status', 'Transaction', 'Type', 'Per_Sqft',
#        'Price'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 79

# %%
df[df.duplicated()]
# Out:
#         Area  BHK  Bathroom   Furnishing      Location       District  \
# 4     1135.0    3       3.0    Furnished    Karol Bagh  Central Delhi
# 18     976.0    2       2.0    Furnished         Okhla     East Delhi
# 85    1800.0    3       3.0    Furnished     Alaknanda    South Delhi
# 96    1000.0    2       2.0    Furnished  Lajpat Nagar    South Delhi
# 110   1400.0    3       3.0    Furnished     Alaknanda    South Delhi
# ...      ...  ...       ...          ...           ...            ...
# 1207  3901.0    4       4.0  Unfurnished   Patel Nagar     West Delhi
# 1208  2306.0    3       3.0  Unfurnished   Patel Nagar     West Delhi
# 1209  4688.0    5       4.0  Unfurnished   Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished   Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished   Patel Nagar     West Delhi
#
#                                                Locality  Parking  \
# 4                             The Amaryllis, Karol Bagh      2.0
# 18                           Godrej South Estate, Okhla      1.0
# 85                        Aravali Apartments, Alaknanda      2.0
# 96                                       Lajpat Nagar 3      1.0
# 110   Tara Apartment, Alaknanda carpet area 1400 sqf...      1.0
# ...                                                 ...      ...
# 1207                  The Leela Sky Villas, Patel Nagar      1.0
# 1208                  The Leela Sky Villas, Patel Nagar      1.0
# 1209                  The Leela Sky Villas, Patel Nagar      1.0
# 1210                  The Leela Sky Villas, Patel Nagar      1.0
# 1211                  The Leela Sky Villas, Patel Nagar      1.0
#
#              Status   Transaction       Type  Per_Sqft      Price
# 4      Almost_ready        Resale  Apartment   22222.0   25000000
# 18    Ready_to_move  New_Property  Apartment   25512.0   24900000
# 85    Ready_to_move  New_Property  Apartment       NaN   20000000
# 96    Ready_to_move        Resale  Apartment   20000.0   20000000
# 110   Ready_to_move        Resale  Apartment   11538.0   19000000
# ...             ...           ...        ...       ...        ...
# 1207   Almost_ready  New_Property  Apartment   23840.0   93000000
# 1208   Almost_ready  New_Property  Apartment   24718.0   57000000
# 1209   Almost_ready  New_Property  Apartment   28797.0  135000000
# 1210   Almost_ready  New_Property  Apartment   23840.0   93000000
# 1211   Almost_ready  New_Property  Apartment   24718.0   57000000
#
# [79 rows x 13 columns]

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (1135, 13)

# %%
df.nunique()
# Out:
# Area           297
# BHK              8
# Bathroom         7
# Furnishing       3
# Location        35
# District         9
# Locality       352
# Parking          8
# Status           2
# Transaction      2
# Type             2
# Per_Sqft       228
# Price          274
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1135 entries, 0 to 1213
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1135 non-null   float64
#  1   BHK          1135 non-null   int64
#  2   Bathroom     1134 non-null   float64
#  3   Furnishing   1135 non-null   object
#  4   Location     1135 non-null   object
#  5   District     1135 non-null   object
#  6   Locality     1135 non-null   object
#  7   Parking      1105 non-null   float64
#  8   Status       1135 non-null   object
#  9   Transaction  1135 non-null   object
#  10  Type         1130 non-null   object
#  11  Per_Sqft     908 non-null    float64
#  12  Price        1135 non-null   int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 124.1+ KB

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         1
# Furnishing       0
# Location         0
# District         0
# Locality         0
# Parking         30
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       227
# Price            0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Location       0
# District       0
# Locality       0
# Parking        0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# Price          0
# dtype: int64

# %%
print(df.shape)
# Out:
# (896, 13)

# %%
df["Furnishing"].unique()
# Out:
# array(['Furnished', 'Semi-Furnished', 'Unfurnished'], dtype=object)

# %%
df["Status"].unique()
# Out:
# array(['Ready_to_move', 'Almost_ready'], dtype=object)

# %%
df["Transaction"].unique()
# Out:
# array(['Resale', 'New_Property'], dtype=object)

# %%
df["Type"].unique()
# Out:
# array(['Apartment', 'Builder_Floor'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
def label(data,columns):
    le = LabelEncoder()
    for column in columns:
        data[column] = le.fit_transform(data[column])
    return data

label(df,["Furnishing","Status","Transaction","Type"])
# Out:
#         Area  BHK  Bathroom  Furnishing     Location       District  \
# 0      950.0    2       2.0           0   Karol Bagh  Central Delhi
# 1      535.0    2       1.0           0   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0           0   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0           0   Karol Bagh  Central Delhi
# 5     1135.0    3       3.0           0   Karol Bagh  Central Delhi
# ...      ...  ...       ...         ...          ...            ...
# 1203  4688.0    5       4.0           2  Patel Nagar     West Delhi
# 1204  3901.0    4       4.0           2  Patel Nagar     West Delhi
# 1205  2306.0    3       3.0           2  Patel Nagar     West Delhi
# 1212   675.0    2       1.0           2  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0           2  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  Status  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0       1
# 1                                 Dev Nagar, Karol Bagh      1.0       1
# 2                                            Karol Bagh      2.0       1
# 3                             The Amaryllis, Karol Bagh      2.0       0
# 5                             The Amaryllis, Karol Bagh      2.0       0
# ...                                                 ...      ...     ...
# 1203                  The Leela Sky Villas, Patel Nagar      1.0       0
# 1204                  The Leela Sky Villas, Patel Nagar      1.0       0
# 1205                  The Leela Sky Villas, Patel Nagar      1.0       0
# 1212                                        Uttam Nagar      1.0       1
# 1213                                        Uttam Nagar      1.0       1
#
#       Transaction  Type  Per_Sqft      Price
# 0               1     0    8761.0   12500000
# 1               0     0    7290.0    3900000
# 2               1     1   14092.0   15000000
# 3               1     0   22222.0   25000000
# 5               1     0   14366.0   25000000
# ...           ...   ...       ...        ...
# 1203            0     0   28797.0  135000000
# 1204            0     0   23840.0   93000000
# 1205            0     0   24718.0   57000000
# 1212            1     1    5794.0    2900000
# 1213            1     1    5794.0    3200000
#
# [896 rows x 13 columns]

# %%
df.tail()
# Out:
#         Area  BHK  Bathroom  Furnishing     Location    District  \
# 1203  4688.0    5       4.0           2  Patel Nagar  West Delhi
# 1204  3901.0    4       4.0           2  Patel Nagar  West Delhi
# 1205  2306.0    3       3.0           2  Patel Nagar  West Delhi
# 1212   675.0    2       1.0           2  Uttam Nagar  West Delhi
# 1213   585.0    2       2.0           2  Uttam Nagar  West Delhi
#
#                                Locality  Parking  Status  Transaction  Type  \
# 1203  The Leela Sky Villas, Patel Nagar      1.0       0            0     0
# 1204  The Leela Sky Villas, Patel Nagar      1.0       0            0     0
# 1205  The Leela Sky Villas, Patel Nagar      1.0       0            0     0
# 1212                        Uttam Nagar      1.0       1            1     1
# 1213                        Uttam Nagar      1.0       1            1     1
#
#       Per_Sqft      Price
# 1203   28797.0  135000000
# 1204   23840.0   93000000
# 1205   24718.0   57000000
# 1212    5794.0    2900000
# 1213    5794.0    3200000

# %%
df["Furnishing"].unique()
# Out:
# array([0, 1, 2])

# %%
df["Type"].unique()
# Out:
# array([0, 1])

# %%
plt.figure(figsize=(15,9))
plt.title("With Outliers.")
sns.boxplot(df)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR = q3-q1
lower = q1 - 1.5*(IQR)
higher = q3 + 1.5*(IQR)
cleaned_data = df[~((df < lower) | (df > higher)).any(axis=1)]
cleaned_data.head()

# %%
df1 = cleaned_data
df1.shape

# %%
plt.figure(figsize=(15,9))
plt.title("After Removing Outliers.")
sns.boxplot(df1)

# %%
df.head()
# Out:
#      Area  BHK  Bathroom  Furnishing    Location       District  \
# 0   950.0    2       2.0           0  Karol Bagh  Central Delhi
# 1   535.0    2       1.0           0  Karol Bagh  Central Delhi
# 2  1280.0    3       3.0           0  Karol Bagh  Central Delhi
# 3  1135.0    3       3.0           0  Karol Bagh  Central Delhi
# 5  1135.0    3       3.0           0  Karol Bagh  Central Delhi
#
#                                             Locality  Parking  Status  \
# 0  DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0       1
# 1                              Dev Nagar, Karol Bagh      1.0       1
# 2                                         Karol Bagh      2.0       1
# 3                          The Amaryllis, Karol Bagh      2.0       0
# 5                          The Amaryllis, Karol Bagh      2.0       0
#
#    Transaction  Type  Per_Sqft     Price
# 0            1     0    8761.0  12500000
# 1            0     0    7290.0   3900000
# 2            1     1   14092.0  15000000
# 3            1     0   22222.0  25000000
# 5            1     0   14366.0  25000000

# %%
df.describe()
# Out:
#                Area         BHK    Bathroom  Furnishing     Parking  \
# count    896.000000  896.000000  896.000000  896.000000  896.000000
# mean    1463.349676    2.757812    2.533482    1.152902    1.421875
# std     1663.375551    0.958610    1.075370    0.643014    0.792797
# min       28.000000    1.000000    1.000000    0.000000    1.000000
# 25%      750.000000    2.000000    2.000000    1.000000    1.000000
# 50%     1100.000000    3.000000    2.000000    1.000000    1.000000
# 75%     1676.250000    3.000000    3.000000    2.000000    2.000000
# max    24300.000000    7.000000    7.000000    2.000000   10.000000
#
#            Status  Transaction        Type       Per_Sqft         Price
# count  896.000000   896.000000  896.000000     896.000000  8.960000e+02
# mean     0.944196     0.604911    0.591518   15701.824777  2.141483e+07
# std      0.229670     0.489143    0.491828   22252.065081  2.738547e+07
# min      0.000000     0.000000    0.000000    1259.000000  1.000000e+06
# 25%      1.000000     0.000000    0.000000    6154.000000  5.122500e+06
# 50%      1.000000     1.000000    1.000000   10700.000000  1.325000e+07
# 75%      1.000000     1.000000    1.000000   16667.000000  2.550000e+07
# max      1.000000     1.000000    1.000000  183333.000000  2.400000e+08

# %%
plt.figure(figsize=(15,9))
corr = df.corr()
sns.heatmap(corr,annot=True)

# %%
sns.pairplot(df)

# %%
sns.countplot(data=df,x=df['Bathroom'])
# Out:
# <Axes: xlabel='Bathroom', ylabel='count'>

# %%
df.hist(figsize=(20,30))
plt.show()

# %%
y = df["Price"]
y # dependent
# Out:
# 0        12500000
# 1         3900000
# 2        15000000
# 3        25000000
# 5        25000000
#           ...
# 1203    135000000
# 1204     93000000
# 1205     57000000
# 1212      2900000
# 1213      3200000
# Name: Price, Length: 896, dtype: int64

# %%
df.drop("Price",axis=1,inplace=True)
df.drop("Locality",axis=1,inplace=True)
x = df
x.head() # independent
# Out:
#      Area  BHK  Bathroom  Furnishing    Location       District  Parking  \
# 0   950.0    2       2.0           0  Karol Bagh  Central Delhi      1.0
# 1   535.0    2       1.0           0  Karol Bagh  Central Delhi      1.0
# 2  1280.0    3       3.0           0  Karol Bagh  Central Delhi      2.0
# 3  1135.0    3       3.0           0  Karol Bagh  Central Delhi      2.0
# 5  1135.0    3       3.0           0  Karol Bagh  Central Delhi      2.0
#
#    Status  Transaction  Type  Per_Sqft
# 0       1            1     0    8761.0
# 1       1            0     0    7290.0
# 2       1            1     1   14092.0
# 3       0            1     0   22222.0
# 5       0            1     0   14366.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=90)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (716, 11)
# (180, 11)
# (716,)
# (180,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)

# %%
from sklearn.metrics import r2_score
y_pred = lr.predict(x_test)
print(r2_score(y_test,y_pred))

# %%
y_pred1 = ridge.predict(x_test)
print(r2_score(y_test,y_pred1))

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)

# %%
y_pred = rfr.predict(x_test)
print(r2_score(y_test,y_pred))

# %%
from sklearn.tree import DecisionTreeRegressor
dtc = DecisionTreeRegressor()
dtc.fit(x_train,y_train)

# %%
y_pred = dtc.predict(x_test)
print(r2_score(y_test,y_pred))

# %%
parameter = {
    'criterion' : ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    'splitter' : ["best", "random"],
    'max_features':["auto", "sqrt", "log2"]
}

# %%
from sklearn.model_selection import GridSearchCV
gsc = GridSearchCV(dtc,param_grid=parameter,scoring = 'accuracy',cv=5)
gsc.fit(x_train,y_train)

# %%
y_pred = gsc.predict(x_test)
print(r2_score(y_test,y_pred))

# %% [markdown]
# # Accuracy of all Algorithms :
# # Linear Regression : 62.36%
# # Ridge : 62.36%
# # RandomForestRegressor: 89.78%
# # Decision tree : 81.75%
# # So, I can Conclude that RandomForestRegressor is best For prediction based on this dataset...
